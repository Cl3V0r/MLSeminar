# %% [markdown]
# # Optimierung und Evaluierung des Sequential bow Modells

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import h5py
import pydot

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report, log_loss
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

from wordcloud import WordCloud
from PIL import Image
from PIL import ImageFilter

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform, normal, qlognormal, randint

from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU, Activation
from keras.regularizers import l2, l1
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping
from keras.models import load_model
from keras.utils import np_utils, plot_model
from keras.optimizers import Adagrad
from keras.losses import binary_crossentropy
# Out:
# Using TensorFlow backend.

# %%
def data_bow():
    x_test = pd.read_hdf("../build/preprocessed/bow_data_500.hdf5",key="test")
    x_train = pd.read_hdf("../build/preprocessed/bow_data_500.hdf5",key="train")
    y_test = x_test.label
    y_train = x_train.label
    x_test= x_test.drop('label',axis=1)
    x_train = x_train.drop('label',axis=1)
    return x_train, y_train, x_test, y_test

# %% [markdown]
# ## First Test

# %%
x_test = pd.read_hdf("../build/preprocessed/bow_data_500.hdf5",key="test")
x_train = pd.read_hdf("../build/preprocessed/bow_data_500.hdf5",key="train")
y_test = x_test.label
y_train = x_train.label
x_test= x_test.drop('label',axis=1)
x_train = x_train.drop('label',axis=1)

# %%
dim = x_train.shape[1]
model = Sequential()
model.add(Dense(1770, kernel_regularizer=l1(2.0036577552673407e-06), input_dim=dim))
model.add(Activation('relu'))
model.add(Dense(9,kernel_regularizer=l2(0.05407632514834404)))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', metrics=['accuracy'],

            optimizer='Adagrad')

model.summary()
    
result = model.fit(x_train.values, y_train.values,
                    batch_size=64,
                    epochs=100,
                    verbose=2,
                    validation_split=0.3)

# %%
def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochen')
    plt.ylabel('Verlust')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validierung'])
    plt.show()
    plt.close()
plot_history(result)

# %% [markdown]
# ## Analyse des Inputs

# %%
x_test = pd.read_hdf("../build/preprocessed/bow_data_500.hdf5",key="test")
x_train = pd.read_hdf("../build/preprocessed/bow_data_500.hdf5",key="train")
X = x_test.append(x_train)

# %% [markdown]
# $$max\left(\frac{(\bar{w_1}-\bar{w_2})^2}{s_1^2+s_2^2}\right)$$

# %%
mu_real = X[X.label==1].mean()
mu_fake = X[X.label==0].mean()
sorted_words = ((mu_real-mu_fake)**2/(np.var(X[X.label==1])**2 + np.var(X[X.label==0])**2)).sort_values(ascending=False).index

words_plot = pd.DataFrame({'Fake':X[X.label==0][sorted_words[1:11]].mean(),'Real':X[X.label==1][sorted_words[1:11]].mean()})
words_plot.plot(kind='bar')
plt.ylabel(r"$\overline{w}$")
plt.legend()
plt.tight_layout()
plt.savefig("../build/plots/data_visualisation.pdf")
plt.show()

# %%
news = pd.read_csv('../data/mixed_news/news_dataset.csv')
news = news.dropna(subset=['title','content'])
news = news[news.content != ' ']
news = news[news.title != ' ']
text_len_real  =  [len(c) for c in news[news['label']=='real'].content]
text_len_fake = [len(c) for c in news[news['label']=='fake'].content]
print("Mittlere textlänge Real: ",np.mean(text_len_real))
print("Mittlere Textlänge Fake: ",np.mean(text_len_fake))
print("Real ist %d länger wie Fake: " % (np.mean(text_len_real)-np.mean(text_len_fake)))

# %% [markdown]
# ## How could the Hyperparameter be distributed
#
# ### Strukture
#
# Größe der ersten und zweiten hidden layer

# %%
x = np.round(np.random.lognormal(6,0.5,10000)/10)*10
plt.hist(x,bins=100)
plt.xlim(0,5000)
plt.show()

# %% [markdown]
# Größer der dritten hidden layer

# %%
x = np.round(np.random.lognormal(4,0.5,10000)/1)*1
plt.hist(x,bins=100)
plt.show()

# %% [markdown]
# ### Regularization

# %%
x =np.random.uniform(0,0.1,10000)
plt.hist(x,bins=100)
plt.show()

# %% [markdown]
# ## Model creation

# %%
def model_structure(x_train, y_train, x_test, y_test):
    dim = x_train.shape[1]
    model = Sequential()
    model.add(Dense(int({{qlognormal(6,0.5,10)}}), input_dim=dim))
    model.add(Activation('relu'))
    
    if {{choice(['three', 'four'])}} == 'four':
        model.add(Dense(int({{qlognormal(6,0.5,10)}})))
        model.add(Activation('relu'))
        
    model.add(Dense(int({{qlognormal(4,0.5,1)}})))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy', metrics=['accuracy'],
                  optimizer='adam')

    result = model.fit(x_train.values, y_train.values,
              batch_size=64,
              epochs=30,
              verbose=2,
              validation_split=0.3)
    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
def model_training(x_train, y_train, x_test, y_test):
    dim = x_train.shape[1]
    model = Sequential()
    model.add(Dense(1770, input_dim=dim))
    model.add(Activation('relu'))
    model.add(Dense(9))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss={{choice(['hinge','binary_crossentropy','squared_hinge'])}}, metrics=['accuracy'],
                  optimizer={{choice(['adam','AdaDelta','Adagrad'])}})

    result = model.fit(x_train.values, y_train.values,
              batch_size=64,
              epochs=30,
              verbose=2,
              validation_split=0.3)
    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
def model_regularization(x_train, y_train, x_test, y_test):
    dim = x_train.shape[1]
    model = Sequential()
    model.add(Dense(1770, kernel_regularizer=l1({{uniform(0,0.1)}}), input_dim=dim))
    model.add(Activation('relu'))
    model.add(Dense(9,kernel_regularizer=l2({{uniform(0,0.1)}})))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy', metrics=['accuracy'],
                  optimizer='Adagrad')

    result = model.fit(x_train.values, y_train.values,
                      batch_size=64,
                      epochs=30,
                      verbose=2,
                      validation_split=0.3)
    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
def model_optimizer(x_train, y_train, x_test, y_test):
    dim = x_train.shape[1]
    model = Sequential()
    model.add(Dense(1770, kernel_regularizer=l1(2.0*10**(-6)), input_dim=dim))
    model.add(Activation('relu'))
    model.add(Dense(9,kernel_regularizer=l2(0.05407632514834404)))
    model.add(Activation('relu'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))

    model.compile(loss='binary_crossentropy', metrics=['accuracy'],
                  optimizer=Adagrad(lr={{uniform(0,1)}}, epsilon=None, decay={{uniform(0,1)}}))

    result = model.fit(x_train.values, y_train.values,
                      batch_size=64,
                      epochs=30,
                      verbose=2,
                      validation_split=0.3)
    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %% [markdown]
# ## Optimization with hyperopt
# Algorithm: Tree of Parzen Estimators
# Optimierung in 3 Schritten:
#     - Struktur (Tiefe (2 oder 3 hidden Layers) und Breite)
#     - Training (loss function und optimizer)
#     - Regularizierung ( L1 für die erste Layer und L2 für 2 und 3)

# %%
trials = Trials()
best_run, best_model = optim.minimize(model=model_structure,
                                      data=data_bow,
                                      algo=tpe.suggest,
                                      max_evals=50,
                                      trials=trials,
                                     notebook_name='Sequential_bow')
print("Best performing model chosen hyper-parameters:")
print(best_run)
best_model.save('../model/best_Hyperopt_NN_bow_struct_500.hdf5')

# %%
trials = Trials()
best_run, best_model = optim.minimize(model=model_training,
                                      data=data_bow,
                                      algo=tpe.suggest,
                                      max_evals=15,
                                      trials=trials,
                                     notebook_name='Sequential_bow')
print("Best performing model chosen hyper-parameters:")
print(best_run)
best_model.save('../model/best_Hyperopt_NN_bow_training_500.hdf5')

# %%
trials = Trials()
best_run, best_model = optim.minimize(model=model_regularization,
                                      data=data_bow,
                                      algo=tpe.suggest,
                                      max_evals=80,
                                      trials=trials,
                                     notebook_name='Sequential_bow')
print("Best performing model chosen hyper-parameters:")
print(best_run)
best_model.save('../model/best_Hyperopt_NN_bow_regularization2_500.hdf5')

# %%
trials = Trials()
best_run, best_model = optim.minimize(model=model_optimizer,
                                      data=data_bow,
                                      algo=tpe.suggest,
                                      max_evals=100,
                                      trials=trials,
                                     notebook_name='Sequential_bow')
print("Best performing model chosen hyper-parameters:")
print(best_run)
best_model.save('../model/best_Hyperopt_NN_bow_optimizer_500.hdf5')

# %% [markdown]
# Beste Regularization:
#
# L1 in der ersten Layer = 0.00010911483516010123
#
# L2 in der zweiten Layer = 0.027248712155710758
#
# lr = 0.12056175158012145
#
# epsilon = 0.1999709211230266
#
# Die Optimierung des Lernrate führt jedoch zu einem Optimizer, der leicht in Nebenmaxima stecken bleibt (hier das Nebenmaxima, dass alles auf real zu schätzen). Daher wird der Standard Lerner verwendet

# %% [markdown]
# ## Evaluation of best model

# %% [markdown]
# ### Train best model
# Neues Training des besten Modells, welches Optimiert bezüglich der Hyperparameter ist

# %%
def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochen')
    plt.ylabel('Verlust')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validierung'])
    #plt.show()
    plt.savefig("../build/plots/bow/500/history_bow_best.pdf")
    plt.close()

# %%
X_train, Y_train, X_test, Y_test = data_bow()
best_model = load_model('../model/best_Hyperopt_NN_bow_regularization2_500.hdf5')
model = Sequential.from_config(best_model.get_config())
print(model.summary())
model.get_config()
# Out:
# WARNING:tensorflow:From /home/larsmoellerherm/.local/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/larsmoellerherm/.local/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_124 (Dense)            (None, 1770)              886770
# _________________________________________________________________
# activation_124 (Activation)  (None, 1770)              0
# _________________________________________________________________
# dense_125 (Dense)            (None, 9)                 15939
# _________________________________________________________________
# activation_125 (Activation)  (None, 9)                 0
# _________________________________________________________________
# dense_126 (Dense)            (None, 1)                 10
# _________________________________________________________________
# activation_126 (Activation)  (None, 1)                 0
# =================================================================
# Total params: 902,719
# Trainable params: 902,719
# Non-trainable params: 0
# _________________________________________________________________
# None
# {'name': 'sequential_42',
#  'layers': [{'class_name': 'Dense',
#    'config': {'name': 'dense_124',
#     'trainable': True,
#     'batch_input_shape': (None, 500),
#     'dtype': 'float32',
#     'units': 1770,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': {'class_name': 'L1L2',
#      'config': {'l1': 0.00010911483695963398, 'l2': 0.0}},
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Activation',
#    'config': {'name': 'activation_124',
#     'trainable': True,
#     'activation': 'relu'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_125',
#     'trainable': True,
#     'units': 9,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': {'class_name': 'L1L2',
#      'config': {'l1': 0.0, 'l2': 0.02724871225655079}},
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Activation',
#    'config': {'name': 'activation_125',
#     'trainable': True,
#     'activation': 'relu'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_126',
#     'trainable': True,
#     'units': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 1.0,
#       'mode': 'fan_avg',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Activation',
#    'config': {'name': 'activation_126',
#     'trainable': True,
#     'activation': 'sigmoid'}}]}

# %%
filepath = '../model/best_Hyperopt_NN_bow_trained_500.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True)
#stopping = EarlyStopping(monitor='val_loss', min_delta=0, restore_best_weights=True)
model.compile(loss='binary_crossentropy',
              optimizer='Adagrad',
              metrics=['accuracy'])
history = model.fit(X_train.values, Y_train.values, validation_split=0.3,
                    epochs=100,batch_size=64, callbacks=[checkpoint])#, stopping])
# Out:
# Train on 13672 samples, validate on 5860 samples
# Epoch 1/100
# 13672/13672 [==============================] - 10s 765us/step - loss: 1.2189 - acc: 0.5622 - val_loss: 0.8206 - val_acc: 0.5635
#
# Epoch 00001: val_loss improved from inf to 0.82060, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 2/100
# 13672/13672 [==============================] - 10s 767us/step - loss: 0.8000 - acc: 0.5818 - val_loss: 0.7560 - val_acc: 0.6005
#
# Epoch 00002: val_loss improved from 0.82060 to 0.75602, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 3/100
# 13672/13672 [==============================] - 9s 673us/step - loss: 0.7501 - acc: 0.6140 - val_loss: 0.7219 - val_acc: 0.6343
#
# Epoch 00003: val_loss improved from 0.75602 to 0.72191, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 4/100
# 13672/13672 [==============================] - 10s 716us/step - loss: 0.7223 - acc: 0.6514 - val_loss: 0.6599 - val_acc: 0.7623
#
# Epoch 00004: val_loss improved from 0.72191 to 0.65993, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 5/100
# 13672/13672 [==============================] - 11s 792us/step - loss: 0.6399 - acc: 0.7836 - val_loss: 0.6974 - val_acc: 0.7693
#
# Epoch 00005: val_loss did not improve from 0.65993
# Epoch 6/100
# 13672/13672 [==============================] - 8s 608us/step - loss: 0.6022 - acc: 0.8139 - val_loss: 0.5771 - val_acc: 0.8346
#
# Epoch 00006: val_loss improved from 0.65993 to 0.57714, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 7/100
# 13672/13672 [==============================] - 9s 629us/step - loss: 0.5621 - acc: 0.8406 - val_loss: 0.5380 - val_acc: 0.8543
#
# Epoch 00007: val_loss improved from 0.57714 to 0.53803, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 8/100
# 13672/13672 [==============================] - 9s 637us/step - loss: 0.5338 - acc: 0.8575 - val_loss: 0.5218 - val_acc: 0.8590
#
# Epoch 00008: val_loss improved from 0.53803 to 0.52176, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 9/100
# 13672/13672 [==============================] - 9s 624us/step - loss: 0.5161 - acc: 0.8645 - val_loss: 0.5418 - val_acc: 0.8391
#
# Epoch 00009: val_loss did not improve from 0.52176
# Epoch 10/100
# 13672/13672 [==============================] - 9s 679us/step - loss: 0.5206 - acc: 0.8517 - val_loss: 0.4938 - val_acc: 0.8683
#
# Epoch 00010: val_loss improved from 0.52176 to 0.49385, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 11/100
# 13672/13672 [==============================] - 11s 832us/step - loss: 0.4986 - acc: 0.8661 - val_loss: 0.4848 - val_acc: 0.8715
#
# Epoch 00011: val_loss improved from 0.49385 to 0.48484, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 12/100
# 13672/13672 [==============================] - 10s 750us/step - loss: 0.4860 - acc: 0.8708 - val_loss: 0.5188 - val_acc: 0.8391
#
# Epoch 00012: val_loss did not improve from 0.48484
# Epoch 13/100
# 13672/13672 [==============================] - 12s 854us/step - loss: 0.4754 - acc: 0.8740 - val_loss: 0.4704 - val_acc: 0.8713
#
# Epoch 00013: val_loss improved from 0.48484 to 0.47043, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 14/100
# 13672/13672 [==============================] - 10s 763us/step - loss: 0.4662 - acc: 0.8763 - val_loss: 0.4643 - val_acc: 0.8746
#
# Epoch 00014: val_loss improved from 0.47043 to 0.46426, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 15/100
# 13672/13672 [==============================] - 10s 749us/step - loss: 0.4572 - acc: 0.8804 - val_loss: 0.4613 - val_acc: 0.8718
#
# Epoch 00015: val_loss improved from 0.46426 to 0.46135, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 16/100
# 13672/13672 [==============================] - 10s 762us/step - loss: 0.4575 - acc: 0.8772 - val_loss: 0.4495 - val_acc: 0.8770
#
# Epoch 00016: val_loss improved from 0.46135 to 0.44947, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 17/100
# 13672/13672 [==============================] - 9s 653us/step - loss: 0.4475 - acc: 0.8810 - val_loss: 0.4484 - val_acc: 0.8744
#
# Epoch 00017: val_loss improved from 0.44947 to 0.44835, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 18/100
# 13672/13672 [==============================] - 10s 743us/step - loss: 0.4391 - acc: 0.8841 - val_loss: 0.4402 - val_acc: 0.8799
#
# Epoch 00018: val_loss improved from 0.44835 to 0.44019, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 19/100
# 13672/13672 [==============================] - 9s 683us/step - loss: 0.4359 - acc: 0.8833 - val_loss: 0.4399 - val_acc: 0.8776
#
# Epoch 00019: val_loss improved from 0.44019 to 0.43986, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 20/100
# 13672/13672 [==============================] - 11s 775us/step - loss: 0.4305 - acc: 0.8851 - val_loss: 0.4387 - val_acc: 0.8771
#
# Epoch 00020: val_loss improved from 0.43986 to 0.43870, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 21/100
# 13672/13672 [==============================] - 9s 638us/step - loss: 0.4265 - acc: 0.8858 - val_loss: 0.4296 - val_acc: 0.8795
#
# Epoch 00021: val_loss improved from 0.43870 to 0.42963, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 22/100
# 13672/13672 [==============================] - 9s 650us/step - loss: 0.4263 - acc: 0.8848 - val_loss: 0.4312 - val_acc: 0.8795
#
# Epoch 00022: val_loss did not improve from 0.42963
# Epoch 23/100
# 13672/13672 [==============================] - 9s 666us/step - loss: 0.4190 - acc: 0.8871 - val_loss: 0.4323 - val_acc: 0.8735
#
# Epoch 00023: val_loss did not improve from 0.42963
# Epoch 24/100
# 13672/13672 [==============================] - 9s 626us/step - loss: 0.4140 - acc: 0.8893 - val_loss: 0.4176 - val_acc: 0.8826
#
# Epoch 00024: val_loss improved from 0.42963 to 0.41757, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 25/100
# 13672/13672 [==============================] - 9s 652us/step - loss: 0.4103 - acc: 0.8894 - val_loss: 0.4156 - val_acc: 0.8834
#
# Epoch 00025: val_loss improved from 0.41757 to 0.41564, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 26/100
# 13672/13672 [==============================] - 10s 704us/step - loss: 0.4084 - acc: 0.8886 - val_loss: 0.4220 - val_acc: 0.8771
#
# Epoch 00026: val_loss did not improve from 0.41564
# Epoch 27/100
# 13672/13672 [==============================] - 9s 659us/step - loss: 0.4064 - acc: 0.8890 - val_loss: 0.4109 - val_acc: 0.8826
#
# Epoch 00027: val_loss improved from 0.41564 to 0.41089, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 28/100
# 13672/13672 [==============================] - 10s 731us/step - loss: 0.4021 - acc: 0.8891 - val_loss: 0.4086 - val_acc: 0.8802
#
# Epoch 00028: val_loss improved from 0.41089 to 0.40864, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 29/100
# 13672/13672 [==============================] - 9s 629us/step - loss: 0.4035 - acc: 0.8886 - val_loss: 0.4058 - val_acc: 0.8816
#
# Epoch 00029: val_loss improved from 0.40864 to 0.40578, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 30/100
# 13672/13672 [==============================] - 9s 626us/step - loss: 0.3964 - acc: 0.8919 - val_loss: 0.4045 - val_acc: 0.8845
#
# Epoch 00030: val_loss improved from 0.40578 to 0.40450, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 31/100
# 13672/13672 [==============================] - 8s 571us/step - loss: 0.3949 - acc: 0.8908 - val_loss: 0.4009 - val_acc: 0.8848
#
# Epoch 00031: val_loss improved from 0.40450 to 0.40094, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 32/100
# 13672/13672 [==============================] - 8s 592us/step - loss: 0.3916 - acc: 0.8918 - val_loss: 0.4021 - val_acc: 0.8831
#
# Epoch 00032: val_loss did not improve from 0.40094
# Epoch 33/100
# 13672/13672 [==============================] - 10s 745us/step - loss: 0.3890 - acc: 0.8925 - val_loss: 0.3986 - val_acc: 0.8828
#
# Epoch 00033: val_loss improved from 0.40094 to 0.39860, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 34/100
# 13672/13672 [==============================] - 7s 496us/step - loss: 0.3876 - acc: 0.8926 - val_loss: 0.3996 - val_acc: 0.8823
#
# Epoch 00034: val_loss did not improve from 0.39860
# Epoch 35/100
# 13672/13672 [==============================] - 8s 607us/step - loss: 0.3876 - acc: 0.8913 - val_loss: 0.3982 - val_acc: 0.8817
#
# Epoch 00035: val_loss improved from 0.39860 to 0.39818, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 36/100
# 13672/13672 [==============================] - 7s 513us/step - loss: 0.3846 - acc: 0.8925 - val_loss: 0.3929 - val_acc: 0.8869
#
# Epoch 00036: val_loss improved from 0.39818 to 0.39286, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 37/100
# 13672/13672 [==============================] - 8s 566us/step - loss: 0.3813 - acc: 0.8934 - val_loss: 0.3911 - val_acc: 0.8846
#
# Epoch 00037: val_loss improved from 0.39286 to 0.39106, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 38/100
# 13672/13672 [==============================] - 8s 574us/step - loss: 0.3806 - acc: 0.8920 - val_loss: 0.3923 - val_acc: 0.8833
#
# Epoch 00038: val_loss did not improve from 0.39106
# Epoch 39/100
# 13672/13672 [==============================] - 9s 624us/step - loss: 0.3773 - acc: 0.8936 - val_loss: 0.3900 - val_acc: 0.8828
#
# Epoch 00039: val_loss improved from 0.39106 to 0.39004, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 40/100
# 13672/13672 [==============================] - 8s 568us/step - loss: 0.3749 - acc: 0.8955 - val_loss: 0.4060 - val_acc: 0.8729
#
# Epoch 00040: val_loss did not improve from 0.39004
# Epoch 41/100
# 13672/13672 [==============================] - 8s 551us/step - loss: 0.3752 - acc: 0.8923 - val_loss: 0.3892 - val_acc: 0.8816
#
# Epoch 00041: val_loss improved from 0.39004 to 0.38915, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 42/100
# 13672/13672 [==============================] - 7s 505us/step - loss: 0.3731 - acc: 0.8960 - val_loss: 0.3865 - val_acc: 0.8834
#
# Epoch 00042: val_loss improved from 0.38915 to 0.38654, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 43/100
# 13672/13672 [==============================] - 7s 518us/step - loss: 0.3716 - acc: 0.8935 - val_loss: 0.3836 - val_acc: 0.8841
#
# Epoch 00043: val_loss improved from 0.38654 to 0.38359, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 44/100
# 13672/13672 [==============================] - 9s 645us/step - loss: 0.3706 - acc: 0.8946 - val_loss: 0.3848 - val_acc: 0.8838
#
# Epoch 00044: val_loss did not improve from 0.38359
# Epoch 45/100
# 13672/13672 [==============================] - 7s 538us/step - loss: 0.3679 - acc: 0.8937 - val_loss: 0.3834 - val_acc: 0.8829
#
# Epoch 00045: val_loss improved from 0.38359 to 0.38340, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 46/100
# 13672/13672 [==============================] - 6s 465us/step - loss: 0.3662 - acc: 0.8963 - val_loss: 0.3814 - val_acc: 0.8863
#
# Epoch 00046: val_loss improved from 0.38340 to 0.38143, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 47/100
# 13672/13672 [==============================] - 6s 472us/step - loss: 0.3653 - acc: 0.8956 - val_loss: 0.3812 - val_acc: 0.8829
#
# Epoch 00047: val_loss improved from 0.38143 to 0.38125, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 48/100
# 13672/13672 [==============================] - 9s 655us/step - loss: 0.3632 - acc: 0.8949 - val_loss: 0.3788 - val_acc: 0.8840
#
# Epoch 00048: val_loss improved from 0.38125 to 0.37880, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 49/100
# 13672/13672 [==============================] - 7s 531us/step - loss: 0.3628 - acc: 0.8955 - val_loss: 0.3767 - val_acc: 0.8840
#
# Epoch 00049: val_loss improved from 0.37880 to 0.37671, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 50/100
# 13672/13672 [==============================] - 8s 585us/step - loss: 0.3616 - acc: 0.8956 - val_loss: 0.3781 - val_acc: 0.8817
#
# Epoch 00050: val_loss did not improve from 0.37671
# Epoch 51/100
# 13672/13672 [==============================] - 6s 443us/step - loss: 0.3600 - acc: 0.8972 - val_loss: 0.3764 - val_acc: 0.8840
#
# Epoch 00051: val_loss improved from 0.37671 to 0.37644, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 52/100
# 13672/13672 [==============================] - 9s 657us/step - loss: 0.3590 - acc: 0.8960 - val_loss: 0.3781 - val_acc: 0.8833
#
# Epoch 00052: val_loss did not improve from 0.37644
# Epoch 53/100
# 13672/13672 [==============================] - 6s 471us/step - loss: 0.3587 - acc: 0.8964 - val_loss: 0.3780 - val_acc: 0.8823
#
# Epoch 00053: val_loss did not improve from 0.37644
# Epoch 54/100
# 13672/13672 [==============================] - 6s 458us/step - loss: 0.3570 - acc: 0.8964 - val_loss: 0.3720 - val_acc: 0.8852
#
# Epoch 00054: val_loss improved from 0.37644 to 0.37203, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 55/100
# 13672/13672 [==============================] - 6s 417us/step - loss: 0.3555 - acc: 0.8960 - val_loss: 0.3790 - val_acc: 0.8809
#
# Epoch 00055: val_loss did not improve from 0.37203
# Epoch 56/100
# 13672/13672 [==============================] - 6s 456us/step - loss: 0.3561 - acc: 0.8964 - val_loss: 0.4236 - val_acc: 0.8543
#
# Epoch 00056: val_loss did not improve from 0.37203
# Epoch 57/100
# 13672/13672 [==============================] - 6s 458us/step - loss: 0.3552 - acc: 0.8974 - val_loss: 0.3786 - val_acc: 0.8826
#
# Epoch 00057: val_loss did not improve from 0.37203
# Epoch 58/100
# 13672/13672 [==============================] - 6s 459us/step - loss: 0.3536 - acc: 0.8973 - val_loss: 0.3696 - val_acc: 0.8855
#
# Epoch 00058: val_loss improved from 0.37203 to 0.36964, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 59/100
# 13672/13672 [==============================] - 7s 494us/step - loss: 0.3508 - acc: 0.8973 - val_loss: 0.3693 - val_acc: 0.8858
#
# Epoch 00059: val_loss improved from 0.36964 to 0.36926, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 60/100
# 13672/13672 [==============================] - 10s 724us/step - loss: 0.3504 - acc: 0.8972 - val_loss: 0.3685 - val_acc: 0.8846
#
# Epoch 00060: val_loss improved from 0.36926 to 0.36854, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 61/100
# 13672/13672 [==============================] - 9s 686us/step - loss: 0.3510 - acc: 0.8972 - val_loss: 0.3676 - val_acc: 0.8843
#
# Epoch 00061: val_loss improved from 0.36854 to 0.36755, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 62/100
# 13672/13672 [==============================] - 11s 773us/step - loss: 0.3488 - acc: 0.8986 - val_loss: 0.3795 - val_acc: 0.8799
#
# Epoch 00062: val_loss did not improve from 0.36755
# Epoch 63/100
# 13672/13672 [==============================] - 9s 628us/step - loss: 0.3481 - acc: 0.8970 - val_loss: 0.3655 - val_acc: 0.8853
#
# Epoch 00063: val_loss improved from 0.36755 to 0.36554, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 64/100
# 13672/13672 [==============================] - 7s 480us/step - loss: 0.3468 - acc: 0.8978 - val_loss: 0.3657 - val_acc: 0.8850
#
# Epoch 00064: val_loss did not improve from 0.36554
# Epoch 65/100
# 13672/13672 [==============================] - 7s 539us/step - loss: 0.3456 - acc: 0.8983 - val_loss: 0.3650 - val_acc: 0.8834
#
# Epoch 00065: val_loss improved from 0.36554 to 0.36503, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 66/100
# 13672/13672 [==============================] - 15s 1ms/step - loss: 0.3468 - acc: 0.8982 - val_loss: 0.3646 - val_acc: 0.8855
#
# Epoch 00066: val_loss improved from 0.36503 to 0.36464, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 67/100
# 13672/13672 [==============================] - 14s 1ms/step - loss: 0.3449 - acc: 0.8994 - val_loss: 0.3729 - val_acc: 0.8797
#
# Epoch 00067: val_loss did not improve from 0.36464
# Epoch 68/100
# 13672/13672 [==============================] - 8s 616us/step - loss: 0.3436 - acc: 0.8982 - val_loss: 0.3639 - val_acc: 0.8853
#
# Epoch 00068: val_loss improved from 0.36464 to 0.36391, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 69/100
# 13672/13672 [==============================] - 11s 801us/step - loss: 0.3428 - acc: 0.8996 - val_loss: 0.3638 - val_acc: 0.8860
#
# Epoch 00069: val_loss improved from 0.36391 to 0.36378, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 70/100
# 13672/13672 [==============================] - 10s 697us/step - loss: 0.3428 - acc: 0.9007 - val_loss: 0.3619 - val_acc: 0.8863
#
# Epoch 00070: val_loss improved from 0.36378 to 0.36191, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 71/100
# 13672/13672 [==============================] - 10s 736us/step - loss: 0.3410 - acc: 0.8989 - val_loss: 0.3615 - val_acc: 0.8860
#
# Epoch 00071: val_loss improved from 0.36191 to 0.36150, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 72/100
# 13672/13672 [==============================] - 11s 829us/step - loss: 0.3405 - acc: 0.8980 - val_loss: 0.3605 - val_acc: 0.8865
#
# Epoch 00072: val_loss improved from 0.36150 to 0.36054, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 73/100
# 13672/13672 [==============================] - 11s 825us/step - loss: 0.3394 - acc: 0.8981 - val_loss: 0.3624 - val_acc: 0.8852
#
# Epoch 00073: val_loss did not improve from 0.36054
# Epoch 74/100
# 13672/13672 [==============================] - 11s 779us/step - loss: 0.3393 - acc: 0.8989 - val_loss: 0.3609 - val_acc: 0.8850
#
# Epoch 00074: val_loss did not improve from 0.36054
# Epoch 75/100
# 13672/13672 [==============================] - 8s 573us/step - loss: 0.3383 - acc: 0.8992 - val_loss: 0.3621 - val_acc: 0.8836
#
# Epoch 00075: val_loss did not improve from 0.36054
# Epoch 76/100
# 13672/13672 [==============================] - 6s 458us/step - loss: 0.3368 - acc: 0.9011 - val_loss: 0.3611 - val_acc: 0.8846
#
# Epoch 00076: val_loss did not improve from 0.36054
# Epoch 77/100
# 13672/13672 [==============================] - 7s 506us/step - loss: 0.3371 - acc: 0.8994 - val_loss: 0.3675 - val_acc: 0.8819
#
# Epoch 00077: val_loss did not improve from 0.36054
# Epoch 78/100
# 13672/13672 [==============================] - 7s 519us/step - loss: 0.3368 - acc: 0.9002 - val_loss: 0.3583 - val_acc: 0.8855
#
# Epoch 00078: val_loss improved from 0.36054 to 0.35828, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 79/100
# 13672/13672 [==============================] - 7s 519us/step - loss: 0.3354 - acc: 0.8989 - val_loss: 0.3587 - val_acc: 0.8858
#
# Epoch 00079: val_loss did not improve from 0.35828
# Epoch 80/100
# 13672/13672 [==============================] - 7s 514us/step - loss: 0.3351 - acc: 0.8996 - val_loss: 0.3569 - val_acc: 0.8867
#
# Epoch 00080: val_loss improved from 0.35828 to 0.35686, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 81/100
# 13672/13672 [==============================] - 7s 486us/step - loss: 0.3339 - acc: 0.9002 - val_loss: 0.3592 - val_acc: 0.8857
#
# Epoch 00081: val_loss did not improve from 0.35686
# Epoch 82/100
# 13672/13672 [==============================] - 8s 561us/step - loss: 0.3336 - acc: 0.8997 - val_loss: 0.3580 - val_acc: 0.8846
#
# Epoch 00082: val_loss did not improve from 0.35686
# Epoch 83/100
# 13672/13672 [==============================] - 9s 649us/step - loss: 0.3326 - acc: 0.9004 - val_loss: 0.3549 - val_acc: 0.8867
#
# Epoch 00083: val_loss improved from 0.35686 to 0.35494, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 84/100
# 13672/13672 [==============================] - 8s 595us/step - loss: 0.3311 - acc: 0.9019 - val_loss: 0.3574 - val_acc: 0.8843
#
# Epoch 00084: val_loss did not improve from 0.35494
# Epoch 85/100
# 13672/13672 [==============================] - 7s 537us/step - loss: 0.3321 - acc: 0.8996 - val_loss: 0.3564 - val_acc: 0.8852
#
# Epoch 00085: val_loss did not improve from 0.35494
# Epoch 86/100
# 13672/13672 [==============================] - 7s 507us/step - loss: 0.3307 - acc: 0.9005 - val_loss: 0.3543 - val_acc: 0.8860
#
# Epoch 00086: val_loss improved from 0.35494 to 0.35430, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 87/100
# 13672/13672 [==============================] - 8s 563us/step - loss: 0.3295 - acc: 0.9008 - val_loss: 0.3529 - val_acc: 0.8862
#
# Epoch 00087: val_loss improved from 0.35430 to 0.35288, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 88/100
# 13672/13672 [==============================] - 7s 531us/step - loss: 0.3296 - acc: 0.9015 - val_loss: 0.3523 - val_acc: 0.8865
#
# Epoch 00088: val_loss improved from 0.35288 to 0.35233, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 89/100
# 13672/13672 [==============================] - 7s 476us/step - loss: 0.3290 - acc: 0.9029 - val_loss: 0.3540 - val_acc: 0.8853
#
# Epoch 00089: val_loss did not improve from 0.35233
# Epoch 90/100
# 13672/13672 [==============================] - 8s 574us/step - loss: 0.3281 - acc: 0.9033 - val_loss: 0.3529 - val_acc: 0.8850
#
# Epoch 00090: val_loss did not improve from 0.35233
# Epoch 91/100
# 13672/13672 [==============================] - 10s 707us/step - loss: 0.3277 - acc: 0.9021 - val_loss: 0.3561 - val_acc: 0.8843
#
# Epoch 00091: val_loss did not improve from 0.35233
# Epoch 92/100
# 13672/13672 [==============================] - 7s 500us/step - loss: 0.3268 - acc: 0.9010 - val_loss: 0.3523 - val_acc: 0.8863
#
# Epoch 00092: val_loss improved from 0.35233 to 0.35227, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 93/100
# 13672/13672 [==============================] - 6s 475us/step - loss: 0.3263 - acc: 0.9021 - val_loss: 0.3522 - val_acc: 0.8870
#
# Epoch 00093: val_loss improved from 0.35227 to 0.35216, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 94/100
# 13672/13672 [==============================] - 6s 431us/step - loss: 0.3262 - acc: 0.9017 - val_loss: 0.3520 - val_acc: 0.8865
#
# Epoch 00094: val_loss improved from 0.35216 to 0.35198, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 95/100
# 13672/13672 [==============================] - 6s 427us/step - loss: 0.3261 - acc: 0.9019 - val_loss: 0.3554 - val_acc: 0.8845
#
# Epoch 00095: val_loss did not improve from 0.35198
# Epoch 96/100
# 13672/13672 [==============================] - 6s 459us/step - loss: 0.3245 - acc: 0.9031 - val_loss: 0.3505 - val_acc: 0.8869
#
# Epoch 00096: val_loss improved from 0.35198 to 0.35054, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 97/100
# 13672/13672 [==============================] - 7s 526us/step - loss: 0.3239 - acc: 0.9027 - val_loss: 0.3528 - val_acc: 0.8865
#
# Epoch 00097: val_loss did not improve from 0.35054
# Epoch 98/100
# 13672/13672 [==============================] - 7s 509us/step - loss: 0.3234 - acc: 0.9039 - val_loss: 0.3512 - val_acc: 0.8853
#
# Epoch 00098: val_loss did not improve from 0.35054
# Epoch 99/100
# 13672/13672 [==============================] - 6s 424us/step - loss: 0.3227 - acc: 0.9033 - val_loss: 0.3496 - val_acc: 0.8879
#
# Epoch 00099: val_loss improved from 0.35054 to 0.34956, saving model to ../model/best_Hyperopt_NN_bow_trained_500.hdf5
# Epoch 100/100
# 13672/13672 [==============================] - 8s 584us/step - loss: 0.3220 - acc: 0.9030 - val_loss: 0.3538 - val_acc: 0.8863
#
# Epoch 00100: val_loss did not improve from 0.34956

# %%
plot_history(history)

# %% [markdown]
# ## Evaluation of best model
# Betrachten des trainierten Modells. Darstellung der Confusion Matrix, Overtraining Plot und ROC Curve

# %%
best_model = load_model('../model/best_Hyperopt_NN_bow_trained_500.hdf5')
y_pred = best_model.predict(X_test.values, batch_size=64, verbose=1)
y_pred_train = best_model.predict(X_train.values, batch_size=64, verbose=1)
y_pred_bool = np.round(y_pred[:,0])
Y_test = pd.DataFrame({"label":Y_test,"prediction":y_pred[:,0],"prediction_bool":y_pred_bool})
Y_train = pd.DataFrame({"label":Y_train,"prediction":y_pred_train[:,0]})
# Out:
# 8371/8371 [==============================] - 1s 112us/step
# 19532/19532 [==============================] - 2s 98us/step

# %%
print(classification_report(Y_test['label'], Y_test['prediction_bool']))
print("Binary Cross Entropie: ",log_loss(Y_test.label, Y_test.prediction))

#Confusion Matrix
cnfn_matrix = pd.crosstab(Y_test['label'], Y_test['prediction_bool'], rownames=['Wahrheit'], colnames=['Schätzung'])
print(cnfn_matrix)
cnfn_matrix.columns = ['Fake','Real']
cnfn_matrix = cnfn_matrix.rename_axis("Schätzung", axis="columns")
cnfn_matrix.rename(index = {0.0: "Fake", 1.0:'Real'}, inplace = True) 
cnfn_matrix = cnfn_matrix/Y_test.shape[0]
sn.heatmap(cnfn_matrix, annot=True , cmap='viridis')
#plt.show()
plt.savefig("../build/plots/bow/500/cnfsn_mtx_bow_best_nn.pdf")
plt.close()

#Overtraining test
plt.hist(Y_test.prediction[Y_test.label == 0],label="fake test", alpha = 0.4, color = "r",density=True)
plt.hist(Y_train.prediction[Y_train.label == 0],label='fake train', alpha = 0.4, color = 'r', histtype='step',density=True)
plt.hist(Y_test.prediction[Y_test.label == 1],label = "real test",alpha = 0.4, color = "b",density=True)
plt.hist(Y_train.prediction[Y_train.label == 1],label='real train', alpha = 0.4, color = 'b', histtype='step',density=True)

plt.xlabel("Geschätzte Likelihood")
plt.ylabel("Dichte")
plt.legend(loc='upper center')
#plt.show()
plt.savefig("../build/plots/bow/500/prob_bow_best_nn.pdf")
plt.close()

fpr = dict()
tpr = dict()
roc_auc = dict()
fpr, tpr, _ = roc_curve(Y_test.label, Y_test.prediction)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC Kurve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
#plt.show()
plt.savefig("../build/plots/bow/500/roc_Hyperopt_bow_best_nn.pdf")
plt.close()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      3658
#            1       0.90      0.89      0.89      4713
#
#    micro avg       0.88      0.88      0.88      8371
#    macro avg       0.88      0.88      0.88      8371
# weighted avg       0.88      0.88      0.88      8371
#
# Binary Cross Entropie:  0.316260521772017
# Schätzung   0.0   1.0
# Wahrheit
# 0          3184   474
# 1           515  4198

# %% [markdown]
# ## Interpretation
#
# ### Wordcloud confusion matrix
#
# Darstellung der Wordhäufigkeiten in WordClouds für FP,FN,TP,TN getrennt

# %%
FP = Y_test[(Y_test.prediction_bool== 1) & (Y_test.label == 0)]
FN = Y_test[(Y_test.prediction_bool== 0) & (Y_test.label == 1)]
TP = Y_test[(Y_test.prediction_bool== 1) & (Y_test.label == 1)]
TN = Y_test[(Y_test.prediction_bool== 0) & (Y_test.label == 0)]
X_FP = X_test.loc[FP.index]
X_FN = X_test.loc[FN.index]
X_TP = X_test.loc[TP.index]
X_TN = X_test.loc[TN.index]

# %%
def plotWordcloud_cnfn(TN,FN,FP,TP):    
    TN = TN.sum().to_dict()
    FN = FN.sum().to_dict()
    FP = FP.sum().to_dict()
    TP = TP.sum().to_dict()
    
    pad = 5
    
    fig = plt.figure(figsize=(15,10),dpi=100)

    ax = plt.subplot(2, 2, 1)
    wordcloud = WordCloud(background_color='black',
                          width=1920,
                          height=1080,
                          mask=np.array(Image.open('../data/pictures/trump_silhouette.png'))
                          ).generate_from_frequencies(TN)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.margins(x=0, y=0)

    ax = plt.subplot(2, 2, 2)
    wordcloud = WordCloud(background_color='black',
                          width=1920,
                          height=1080,
                          mask= np.array(Image.open('../data/pictures/trump_silhouette.png'))
                          ).generate_from_frequencies(FP)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.margins(x=0, y=0)

    ax = plt.subplot(2, 2, 3)
    wordcloud = WordCloud(background_color='black',
                          width=1920,
                          height=1080,
                          mask=np.array(Image.open('../data/pictures/USA.jpg'))
                          ).generate_from_frequencies(FN)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.margins(x=0, y=0)

    plt.subplot(2, 2, 4)
    wordcloud = WordCloud(background_color='black',
                          width=1920,
                          height=1080,
                          mask=np.array(Image.open('../data/pictures/USA.jpg'))
                          ).generate_from_frequencies(TP)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    
    plt.figtext(0.5, 1.09, r"Prediction", {'fontsize': 30},
         horizontalalignment='center',
         verticalalignment='top')
    plt.figtext(0.25, 1.02, r"fake", {'fontsize': 20},
         horizontalalignment='center',
         verticalalignment='bottom',)
    plt.figtext(0.75, 1.02, r"real", {'fontsize': 20},
         horizontalalignment='center',
         verticalalignment='bottom',)
    
    plt.figtext(-0.07, 0.5, r"Actual", {'fontsize': 30},
         horizontalalignment='left',
         verticalalignment='center',
         rotation=90)
    plt.figtext(0.00, 0.75, r"fake", {'fontsize': 20},
         horizontalalignment='right',
         verticalalignment='center',)
    plt.figtext(0.00, 0.25, r"real", {'fontsize': 20},
         horizontalalignment='right',
         verticalalignment='center',)
    
    plt.margins(x=0, y=0)
    plt.tight_layout()
    #plt.show()
    plt.savefig("../build/plots/bow/500/cnfn_wordcloud.pdf", bbox_inches = 'tight')
    plt.close()

# %%
plotWordcloud_cnfn(X_TN,X_FN,X_FP,X_TP)

# %% [markdown]
# ### Wordcloud fake real news

# %%
def plotWordcloud(content,t):
    if(t!=""):
       mask = np.array(Image.open('../data/pictures/'+t))
    else:
        mask=None
        

    content = content.sum().to_dict()
    wordcloud = WordCloud(background_color='black',
                      width=1920,
                      height=1080,
                      mask=mask
                      ).generate_from_frequencies(content)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.margins(x=0, y=0)

# %%
X = X_test.append(X_train)
y = Y_test.append(Y_train)
plt.figure(dpi=200)
plotWordcloud(X[y.label==0],"trump_silhouette.png")
#plt.show()
plt.savefig("../build/plots/fake_wordcloud.pdf",bbox_inches='tight',pad_inches = 0)
plt.close()
plt.figure(dpi=200)
plotWordcloud(X[y.label==1],"USA.jpg")
#plt.show()
plt.savefig("../build/plots/real_wordcloud.pdf",bbox_inches='tight',pad_inches = 0)
plt.close()

# %% [markdown]
# ## Untersuchung der first layer
#
# Summieren der Beträge aller Gewichte eines Neurons ohne Offset und anschließende Darstellung in WordCloud

# %%
words = X_test.columns
first_weights = best_model.layers[0].get_weights()[0]
first_weights = pd.DataFrame(first_weights.transpose())
first_weights.columns = words
first_weightabs = np.abs(first_weights)
first_weightsum = first_weightabs.sum(axis=0)
content = np.abs(first_weightsum).to_dict()
wordcloud = WordCloud(background_color='black',
                      width=1920,
                      height=1080
                      ).generate_from_frequencies(content)
plt.figure(dpi=100)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
#plt.show()
plt.savefig("../build/plots/bow/500/weights_wordcloud.pdf")
plt.close()

# %% [markdown]
# Untersuchung der Confusion Matrix mithilfe der wichtigsten 10 Wörter

# %%
sorted_weights = first_weightsum.sort_values(ascending=False)
best_words = sorted_weights[:10].index

fig = plt.figure(figsize=(15,10),dpi=100)

ax = plt.subplot(2, 2, 1)
(X_TN[best_words].sum()/X_TN.shape[0]).plot(kind='bar',label="TN",color='r')
plt.margins(x=0, y=0)
plt.ylabel("mittlere Worthäufigkeit")
plt.ylim(0.01,60)
plt.yscale("log")

ax = plt.subplot(2, 2, 2)
(X_FP[best_words].sum()/X_FP.shape[0]).plot(kind='bar',label="FP",color='g')
plt.margins(x=0, y=0)
plt.ylabel("mittlere Worthäufigkeit")
plt.ylim(0.01,60)
plt.yscale("log")

ax = plt.subplot(2, 2, 3)
(X_FN[best_words].sum()/X_FN.shape[0]).plot(kind='bar',label="FN",color='k')
plt.margins(x=0, y=0)
plt.ylabel("mittlere Worthäufigkeit")
plt.ylim(0.01,60)
plt.yscale("log")

plt.subplot(2, 2, 4)
(X_TP[best_words].sum()/X_TP.shape[0]).plot(kind='bar',label="TP",color='b')
plt.margins(x=0, y=0)
plt.ylabel("mittlere Worthäufigkeit")
plt.ylim(0.01,60)
plt.yscale("log")
    
plt.figtext(0.5, 1.09, r"Schätzung", {'fontsize': 30},
     horizontalalignment='center',
     verticalalignment='top')
plt.figtext(0.25, 1.02, r"Fake", {'fontsize': 20},
     horizontalalignment='center',
     verticalalignment='bottom',)
plt.figtext(0.75, 1.02, r"Real", {'fontsize': 20},
     horizontalalignment='center',
     verticalalignment='bottom',)
    
plt.figtext(-0.07, 0.5, r"Wahrheit", {'fontsize': 30},
     horizontalalignment='left',
     verticalalignment='center',
     rotation=90)
plt.figtext(0.00, 0.75, r"Fake", {'fontsize': 20},
     horizontalalignment='right',
     verticalalignment='center',)
plt.figtext(0.00, 0.25, r"Real", {'fontsize': 20},
     horizontalalignment='right',
     verticalalignment='center',)
    
plt.margins(x=0, y=0)
plt.tight_layout()
#plt.show()
plt.savefig("../build/plots/bow/500/cnfn_hist.pdf", bbox_inches = 'tight')
plt.close()

# %% [markdown]
# ### RF Vergleichsmodell
# Training einer RF auf dem bow Input und Evaluierung

# %%
RF = RandomForestClassifier(n_estimators=100, max_depth=10,random_state=0,criterion='entropy')
RF.fit(X_train.values,Y_train.label.values)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_pred_bool_RF = RF.predict(X_test.values)
y_pred_RF = RF.predict_proba(X_test.values)
y_pred_RF = y_pred_RF[:,1]
y_pred_train_RF = RF.predict_proba(X_train.values)
y_pred_train_RF = y_pred_train_RF[:,1]
Y_test['prediction_RF'] = y_pred_RF
Y_test['prediction_bool_RF'] = y_pred_bool_RF
Y_train['prediction_RF'] = y_pred_train_RF

# %%
print(classification_report(Y_test.label, Y_test.prediction_bool_RF))

#Confusion Matrix
cnfn_matrix = pd.crosstab(Y_test.label, Y_test.prediction_bool_RF, rownames=['Wahrheit'], colnames=['Schätzung'])
print(cnfn_matrix)
cnfn_matrix.columns = ['Fake','Real']
cnfn_matrix = cnfn_matrix.rename_axis("Schätzung", axis="columns")
cnfn_matrix.rename(index = {0.0: "Fake", 1.0:'Real'}, inplace = True) 
cnfn_matrix = cnfn_matrix/Y_test.shape[0]
sn.heatmap(cnfn_matrix, annot=True , cmap='viridis')
#plt.show()
plt.savefig("../build/plots/bow/500/RF/cnfsn_mtx_bow_best_nn.pdf")
plt.close()

#Overtraining test
bin_edges = np.linspace(0,1,11)
plt.hist(Y_test.prediction_RF[Y_test.label == 0],label="fake test", alpha = 0.4, color = "r",density=True,bins=bin_edges)
plt.hist(Y_train.prediction_RF[Y_train.label == 0],label='fake train', alpha = 0.4, color = 'r', histtype='step',density=True,bins=bin_edges)
plt.hist(Y_test.prediction_RF[Y_test.label == 1],label = "real test",alpha = 0.4, color = "b",density=True,bins=bin_edges)
plt.hist(Y_train.prediction_RF[Y_train.label == 1],label='real train', alpha = 0.4, color = 'b', histtype='step',density=True,bins=bin_edges)

plt.xlabel("Geschätzte Likelihood")
plt.ylabel("Dichte")
plt.legend(loc='upper center')
#plt.show()
plt.savefig("../build/plots/bow/500/RF/prob_bow_best_nn.pdf")
plt.close()

fpr_RF = dict()
tpr_RF = dict()
roc_auc_RF = dict()
fpr_RF, tpr_RF, _ = roc_curve(Y_test.label, Y_test.prediction_RF)
roc_auc_RF = auc(fpr_RF, tpr_RF)

plt.figure()
lw = 2
plt.plot(fpr_RF, tpr_RF, color='darkorange',
         lw=lw, label='ROC Kurve (AUC = %0.2f)' % roc_auc_RF)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
#plt.show()
plt.savefig("../build/plots/bow/500/RF/roc_Hyperopt_bow_best_nn.pdf")
plt.close()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79      3658
#            1       0.81      0.91      0.86      4713
#
#    micro avg       0.83      0.83      0.83      8371
#    macro avg       0.84      0.82      0.83      8371
# weighted avg       0.84      0.83      0.83      8371
#
# Schätzung     0     1
# Wahrheit
# 0          2679   979
# 1           405  4308

# %% [markdown]
# ### Comparison
# Vergleich des Sequential mit dem RF in der ROC Curve

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='Sequential (AUC = %0.2f)' % roc_auc)
plt.plot(fpr_RF, tpr_RF, color='darkred',
         lw=lw, label='RandomForest (AUC = %0.2f)' % roc_auc_RF)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
#plt.show()
plt.savefig("../build/plots/bow/500/roc_comparison.pdf")
plt.close()

# %% [markdown]
# ## Draw Modell

# %%
from graphviz import Digraph

m = Digraph(name='Modell', node_attr={'shape': 'record'})
m.attr(rankdir='LR')

m.node("input", r"𝐄𝐢𝐧𝐠𝐚𝐧𝐠𝐬 𝐋𝐚𝐠𝐞 | 500 Wörter ")
m.node("first", r"𝐄𝐫𝐬𝐭𝐞 𝐋𝐚𝐠𝐞|Neuronen: 1770|Aktivierung: ReLu|L1: 0.00011")
m.node("second", r"𝐙𝐰𝐞𝐢𝐭𝐞 𝐋𝐚𝐠𝐞|Neuronen: 9|Aktivierung: ReLu|L2: 0.0272")
m.node("output", r"𝐀𝐮𝐬𝐠𝐚𝐧𝐠𝐬 𝐋𝐚𝐠𝐞|Neuronen: 1 |Aktivierung: Sigmoid")

m.edge('input', 'first')
m.edge('first', 'second')
m.edge('second', 'output')

m.render('../build/plots/bow/500/modell_scheme', view=True)
